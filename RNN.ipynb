# %%
# !pip install tensorflow

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Input
from tensorflow.keras.models import Model

# %%
mnist=keras.datasets.mnist
(x_train,y_train), (x_test,y_test) = mnist.load_data()
x_train , x_test=x_train / 255.0, x_test/255.0

# %%
import matplotlib.pyplot as plt
plt.imshow(x_train[125])

# %%
x_train.shape

# %%
y_train[125]

# %%
model = keras.Sequential([
    layers.Flatten(input_shape=(28,28,1)),
    layers.Dense(128,activation='relu'),
    layers.Dense(10,activation='softmax')
])

# %%
model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# %%
outcome=model.fit(x_train,y_train,validation_split=0.1,epochs=10)
# Out:
# Epoch 1/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 13s 7ms/step - accuracy: 0.9220 - loss: 0.2715 - val_accuracy: 0.9625 - val_loss: 0.1303
# Epoch 2/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9635 - loss: 0.1214 - val_accuracy: 0.9735 - val_loss: 0.0887
# Epoch 3/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9758 - loss: 0.0816 - val_accuracy: 0.9740 - val_loss: 0.0837
# Epoch 4/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.9816 - loss: 0.0609 - val_accuracy: 0.9783 - val_loss: 0.0737
# Epoch 5/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9857 - loss: 0.0472 - val_accuracy: 0.9798 - val_loss: 0.0756
# Epoch 6/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9883 - loss: 0.0376 - val_accuracy: 0.9782 - val_loss: 0.0772
# Epoch 7/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9914 - loss: 0.0287 - val_accuracy: 0.9775 - val_loss: 0.0747
# Epoch 8/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9931 - loss: 0.0242 - val_accuracy: 0.9807 - val_loss: 0.0725
# Epoch 9/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 6s 4ms/step - accuracy: 0.9938 - loss: 0.0204 - val_accuracy: 0.9798 - val_loss: 0.0724
# Epoch 10/10
# 1688/1688 ━━━━━━━━━━━━━━━━━━━━ 8s 5ms/step - accuracy: 0.9954 - loss: 0.0158 - val_accuracy: 0.9818 - val_loss: 0.0770

# %%
input_shape=(28,28)
inputs = layers.Input(shape=input_shape)
rnn_layer=LSTM(128)(inputs)
outputs=Dense(10,activation='softmax')(rnn_layer)
model= Model(inputs=inputs,outputs=outputs)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_706/3770437112.py in <cell line: 0>()
#       3 rnn_layer=LSTM(128)(inputs)
#       4 outputs=Dense(10,activation='softmax')(rnn_layer)
# ----> 5 model= Model(inputs=inputs,outputs=outputs)
#
# NameError: name 'Model' is not defined
