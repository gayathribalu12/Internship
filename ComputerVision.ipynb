# %%
import cv2
cv2.__version__
# Out:
# '4.13.0'

# %%
img=cv2.imread("/content/images.jpg")

# %%
print(img)
# Out:
# [[[158 142 125]
#   [160 144 127]
#   [163 147 130]
#   ...
#   [206 190 174]
#   [206 190 174]
#   [206 190 174]]
#
#  [[159 143 126]
#   [161 145 128]
#   [164 148 131]
#   ...
#   [205 189 173]
#   [205 189 173]
#   [205 189 173]]
#
#  [[161 145 128]
#   [163 147 130]
#   [165 149 132]
#   ...
#   [205 189 173]
#   [205 189 173]
#   [205 189 173]]
#
#  ...
#
#  [[ 30  20  20]
#   [ 23  13  13]
#   [ 22  12  12]
#   ...
#   [ 49  37  35]
#   [ 49  37  35]
#   [ 50  38  36]]
#
#  [[ 35  25  25]
#   [ 30  20  20]
#   [ 29  19  19]
#   ...
#   [ 44  32  30]
#   [ 45  33  31]
#   [ 46  34  32]]
#
#  [[ 28  18  18]
#   [ 26  16  16]
#   [ 26  16  16]
#   ...
#   [ 49  37  35]
#   [ 51  39  37]
#   [ 53  41  39]]]

# %%
from google.colab.patches import cv2_imshow
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>

# %%
#imgg black and white
img2=cv2.imread("/content/images.jpg",0)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=L size=335x597>

# %%
#storing the black and white imaggg
cv2.imwrite("BW.jpg",img2)
# Out:
# True

# %%
#size
print(img.size)
# Out:
# 599985

# %%
#shape
print(img.shape)
# Out:
# (597, 335, 3)

# %%
#channels
print(type(img))
# Out:
# <class 'numpy.ndarray'>

# %%
#slicing
img2 = img[220:520, 20:315]
img2
# Out:
# array([[[ 98,  86,  76],
#         [ 99,  87,  77],
#         [ 99,  87,  77],
#         ...,
#         [116, 100,  84],
#         [115,  99,  83],
#         [114,  98,  82]],
#
#        [[ 99,  87,  77],
#         [100,  88,  78],
#         [101,  89,  79],
#         ...,
#         [117, 101,  85],
#         [116, 100,  84],
#         [115,  99,  83]],
#
#        [[101,  89,  77],
#         [101,  89,  77],
#         [102,  90,  78],
#         ...,
#         [118, 102,  86],
#         [117, 101,  85],
#         [115,  99,  83]],
#
#        ...,
#
#        [[ 40,  30,  30],
#         [ 31,  21,  21],
#         [ 43,  33,  33],
#         ...,
#         [ 56,  44,  42],
#         [ 56,  44,  42],
#         [ 56,  44,  42]],
#
#        [[ 39,  29,  29],
#         [ 45,  35,  35],
#         [ 38,  28,  28],
#         ...,
#         [ 58,  46,  44],
#         [ 58,  46,  44],
#         [ 58,  46,  44]],
#
#        [[ 38,  28,  28],
#         [ 61,  51,  51],
#         [ 34,  24,  24],
# ...

# %%
#image_rotating
img2=cv2.rotate(img,cv2.ROTATE_90_COUNTERCLOCKWISE)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=597x335>

# %%
#flipping ---- 1 for vertical
img2=cv2.flip(img,1)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>

# %%
#flipping
img2=cv2.flip(img,0)
from google.colab.patches import cv2_imshow
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>

# %%
#resizing
img3=cv2.resize(img,(250,250))
from google.colab.patches import cv2_imshow
cv2_imshow(img3)
# Out:
# <PIL.Image.Image image mode=RGB size=250x250>

# %%
#imgg blurring
img4=cv2.blur(img,(1,75))
from google.colab.patches import cv2_imshow
cv2_imshow(img4)
# Out:
# <PIL.Image.Image image mode=RGB size=335x597>
