# %%
# !pip install gradio

# %%
def add(number1,number2):
  Sum=number1+number2
  return sum

# %%
import gradio as gr
i=gr.Interface(fn=add,inputs=["number","number"],outputs="number")
i.launch(debug=True)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. This cell will run indefinitely so that you can see errors and logs. To turn off, set debug=False in launch().
# * Running on public URL: https://712939b34c8810eb73.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://712939b34c8810eb73.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Created dataset file at: .gradio/flagged/dataset1.csv

# %% [markdown]
# STREAMLIT
#
# in colab we have to create a local tunnel
#
# ```
# # This is formatted as code
# ```

# %%
st.title
st.header
st.text area  # height=200
st.slider #min value=50， max value=200, value=100, step=10
st.selectbox #options=[1, 2, 3], index=0
st.button
st.spinner
st.write
st.markdown
st.sidebar.markdown
st.sidebar.info
st.sidebar.write
